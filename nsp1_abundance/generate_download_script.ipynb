# %%
import urllib

import shutil
import urllib.request as request
from contextlib import closing

import os
import io
import gzip
import tarfile

import xml.etree.ElementTree as ET

import re

import json

from datetime import datetime


###############################################################
### EXCEPTIONS

class GeoError(Exception):
    """Base class for GEO Errors"""
    pass

class GeoRetrivalError(GeoError):
    """Problem in retriving data from GEO """
    pass

class GeoParseError(GeoError):
    """Problem in parsing data from GEO """
    pass

###############################################################


##############################################################
### HELPER FUNCTIONS

def sanitize_sra(s):
    """
    To avoid redundancy and ambiguity, we search for SRR ids
    surrounded by > and <. So we remove those boundary charactgers.

    >SRR12345< -> SRR12345
    """
    return s.replace("<", "").replace(">", "")



def extract_srr_from_str(srr_page_text):
    """
    extracts the SRR accession numbers
    from the xml string of the SRA page.

    Returns a list of SRR accession IDs.
    """

    re_pattern   = re.compile(r">SRR[0-9]+<", re.DOTALL)
    raw_finds    = re_pattern.findall(srr_page_text)
    actual_finds = list( map( sanitize_sra , raw_finds ) )

    return actual_finds



def get_srr_accessions(sra_url):
    """
    Returns a list of SRR accession ids from the sra url
    Example URL: https://www.ncbi.nlm.nih.gov/sra?term=SRX9173299
    """
    page_text = request.urlopen(sra_url).read().decode("utf-8")
    return extract_srr_from_str(page_text)



def sanitize_text(t):
    """
    Clears all white space from the text
    We keep this as a separate function in case
    text needs further sanitizing
    """
    return t.strip()



def parse_sample(sample_node):
    """
    Reads experiment info from the XML tree
    Returns a dictionary containing experiment metadata
    The dictionary also contains
    SRA accession ids of the sequencing data
    """
    sample_dict = {}

    for x in sample_node:
        if x.tag.lower().endswith("title"):
            sample_dict["title"] =  sanitize_text( x.text )
        if x.tag.lower().endswith("accession"):
            sample_dict["accession"] =  sanitize_text( x.text )
        if x.tag.lower().endswith("channel"):
            for c in x:
                if c.tag.lower().endswith("organism"):
                    sample_dict["organism"] =  sanitize_text( c.text )
                if c.tag.lower().endswith("characteristics"):
                    if c.attrib.get("tag", "").lower() == "cell line":
                        sample_dict["cell_line"] =  sanitize_text( c.text )
        if x.tag.lower().endswith("status"):
            for s in x:
                if s.tag.lower().endswith("submission-date"):
                    sample_dict["submission-date"] =  sanitize_text( s.text )

        if x.tag.lower().endswith("relation"):
            if x.attrib.get("type", "").lower() == "sra":
                sample_dict["sra_link"] = x.attrib["target"]
                sample_dict["srr_ids"]  = get_srr_accessions( x.attrib["target"] )

    return sample_dict



def parse_study_string(xml_string):
    """
    parses the xml string and returns a dictionary
    containing the metadata of the study and its experiments
    """

    study_root     = ET.fromstring(xml_string)
    geo_study_dict = { "experiments" : dict() }

    for a in study_root:
        if a.tag.lower().endswith("series"):
            for s in a:
                if s.tag.lower().endswith("accession"):
                    geo_study_dict["accession"] = s.text
                if s.tag.lower().endswith("title"):
                    geo_study_dict["title"] = s.text
                if s.tag.lower().endswith("summary"):
                    geo_study_dict["abstract"] = s.text
                if s.tag.lower().endswith("type"):
                    geo_study_dict["type"] = s.text
                if s.tag.lower().endswith("overall-design"):
                    geo_study_dict["overall-design"] = s.text

                if s.tag.lower().endswith("status"):
                    for t in s:
                        if t.tag.lower().endswith("submission-date"):
                            geo_study_dict["submission-date"] = t.text

        if a.tag.lower().endswith("sample"):
            geo_study_dict["experiments"][a.attrib["iid"]] = parse_sample(a)

    return geo_study_dict



def read_miniml_from_GEO(file_ftp_path):
    """
    returns the contents of the xml file as a string

    By default, the file is in tgz = tar.gz format.
    So the file needs to be unzipped and untarred
    There should be a file inside the tar file with the same name except for the tgz
    For example, if the path is
    "ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE158nnn/GSE158374/miniml/GSE158374_family.xml.tgz"
    then there should be the file
    "GSE158374_family.xml" in the tar.gz file.
    We extract that file and read its contetns to a string
    This string is return
    """

    # We assume the filename ends with .tgz
    # so we leave it out
    name_pieces   = file_ftp_path.split("/")[-1].split(".")
    xml_file_name = ".".join(name_pieces[:-1])


    with closing(request.urlopen(file_ftp_path)) as ftp_stream:
        mybuffer     = io.BytesIO(ftp_stream.read())
        mytar        = tarfile.open(fileobj=mybuffer,mode =  'r')
        xml_contents = mytar.extractfile(xml_file_name)
        contents     = xml_contents.read().decode("utf-8")

        return contents



def get_study_metadata_from_miniml(file_ftp_url):
    """
    Extracts the metadata of the study from the given ftp miniml file path.

    Example path: ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE158nnn/GSE158374/miniml/GSE158374_family.xml.tgz
    """

    miniml_file_contents = read_miniml_from_GEO(file_ftp_url)
    study_metadata_dict  = parse_study_string(miniml_file_contents)

    return study_metadata_dict


def get_html_page_of_study(study_accession):

    study_geo_url = "https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc={}".format( study_accession )

    try:
        with closing(request.urlopen(study_geo_url)) as http_stream:
            html_code = http_stream.read().decode("utf-8")
    except URLError:
        return ""

    return html_code


def get_miniml_url(html_code, study_accession):
    search_pattern  = re.compile("ftp://ftp.ncbi.nlm.nih.gov/geo/series/[A-Z]*[0-9]*[n]*/[A-Z]*[0-9]*/miniml/")

    search_result   = search_pattern.findall(html_code)

    if len(search_result) == 0:
        return ""

    miniml_folder   = search_result[0]
    m               = re.match(r".*/(?P<study_id>[A-Z]+[0-9]+)/.*", miniml_folder)
    obtained_acc    = m.group("study_id")

    assert study_accession == obtained_acc

    miniml_url      = "{}{}_family.xml.tgz"\
                      .format(miniml_folder, study_accession)

    return miniml_url


def get_study_dict_from_geo_id(study_accession):
    html_code = get_html_page_of_study(study_accession)

    if not html_code:
        print("Couldn't find the study {}".format(study_accession))
        return None

    study_miniml_url = get_miniml_url(html_code, study_accession)

    if not study_miniml_url:
        print("Couldn't find the study {}".format(study_accession))
        return None

    study_dict = get_study_metadata_from_miniml(study_miniml_url)

    return study_dict

# %%
study_dict = get_study_dict_from_geo_id("GSE150316")

# %%
study_dict
# Out:
# {'experiments': {'GSM4546576': {'submission-date': '2020-05-11',
#    'title': 'case1-lung1',
#    'accession': 'GSM4546576',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8325539',
#    'srr_ids': ['SRR11772358']},
#   'GSM4546577': {'submission-date': '2020-05-11',
#    'title': 'case1-lung2',
#    'accession': 'GSM4546577',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8325540',
#    'srr_ids': ['SRR11772359']},
#   'GSM4546578': {'submission-date': '2020-05-11',
#    'title': 'case1-lung3',
#    'accession': 'GSM4546578',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8325541',
#    'srr_ids': ['SRR11772360']},
#   'GSM4546579': {'submission-date': '2020-05-11',
#    'title': 'case1-lung4',
#    'accession': 'GSM4546579',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8325542',
#    'srr_ids': ['SRR11772361']},
#   'GSM4546580': {'submission-date': '2020-05-11',
#    'title': 'case1-heart1',
#    'accession': 'GSM4546580',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8325543',
#    'srr_ids': ['SRR11772362']},
#   'GSM4546581': {'submission-date': '2020-05-11',
#    'title': 'case2-lung1',
#    'accession': 'GSM4546581',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8325544',
#    'srr_ids': ['SRR11772363']},
#   'GSM4546582': {'submission-date': '2020-05-11',
#    'title': 'case2-lung2',
#    'accession': 'GSM4546582',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8325545',
#    'srr_ids': ['SRR11772364']},
#   'GSM4546583': {'submission-date': '2020-05-11',
#    'title': 'case2-jejunum1',
#    'accession': 'GSM4546583',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8325546',
#    'srr_ids': ['SRR11772365']},
#   'GSM4546584': {'submission-date': '2020-05-11',
#    'title': 'case2-lung3',
#    'accession': 'GSM4546584',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8325547',
#    'srr_ids': ['SRR11772366']},
#   'GSM4546585': {'submission-date': '2020-05-11',
#    'title': 'case2-heart1',
#    'accession': 'GSM4546585',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8325548',
#    'srr_ids': ['SRR11772367']},
#   'GSM4546586': {'submission-date': '2020-05-11',
#    'title': 'case3-lung1',
#    'accession': 'GSM4546586',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8325549',
#    'srr_ids': ['SRR11772368']},
#   'GSM4546587': {'submission-date': '2020-05-11',
#    'title': 'case3-heart1',
#    'accession': 'GSM4546587',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8325550',
#    'srr_ids': ['SRR11772369']},
#   'GSM4546588': {'submission-date': '2020-05-11',
#    'title': 'case3-lung2',
#    'accession': 'GSM4546588',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8325551',
#    'srr_ids': ['SRR11772370']},
#   'GSM4546589': {'submission-date': '2020-05-11',
#    'title': 'case4-lung1',
#    'accession': 'GSM4546589',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8325552',
#    'srr_ids': ['SRR11772371']},
#   'GSM4546590': {'submission-date': '2020-05-11',
#    'title': 'case4-heart1',
#    'accession': 'GSM4546590',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8325553',
#    'srr_ids': ['SRR11772372']},
#   'GSM4546591': {'submission-date': '2020-05-11',
#    'title': 'case4-liver1',
#    'accession': 'GSM4546591',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8325554',
#    'srr_ids': ['SRR11772373']},
#   'GSM4546592': {'submission-date': '2020-05-11',
#    'title': 'case4-lung2',
#    'accession': 'GSM4546592',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8325555',
#    'srr_ids': ['SRR11772374']},
#   'GSM4546593': {'submission-date': '2020-05-11',
#    'title': 'case4-kidney1',
#    'accession': 'GSM4546593',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8325556',
#    'srr_ids': ['SRR11772375']},
#   'GSM4546594': {'submission-date': '2020-05-11',
#    'title': 'case4-heart2',
#    'accession': 'GSM4546594',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8325557',
#    'srr_ids': ['SRR11772376']},
#   'GSM4546595': {'submission-date': '2020-05-11',
#    'title': 'case4-bowel1',
#    'accession': 'GSM4546595',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8325558',
#    'srr_ids': ['SRR11772377']},
#   'GSM4546596': {'submission-date': '2020-05-11',
#    'title': 'case5-lung1',
#    'accession': 'GSM4546596',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8325559',
#    'srr_ids': ['SRR11772378']},
#   'GSM4546597': {'submission-date': '2020-05-11',
#    'title': 'case5-lung2',
#    'accession': 'GSM4546597',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8325560',
#    'srr_ids': ['SRR11772379']},
#   'GSM4546598': {'submission-date': '2020-05-11',
#    'title': 'case5-lung3',
#    'accession': 'GSM4546598',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8325561',
#    'srr_ids': ['SRR11772380']},
#   'GSM4546599': {'submission-date': '2020-05-11',
#    'title': 'case5-lung4',
#    'accession': 'GSM4546599',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8325562',
#    'srr_ids': ['SRR11772381']},
#   'GSM4546600': {'submission-date': '2020-05-11',
#    'title': 'case5-fat1',
#    'accession': 'GSM4546600',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8325563',
#    'srr_ids': ['SRR11772382']},
#   'GSM4546601': {'submission-date': '2020-05-11',
#    'title': 'case5-lung5',
#    'accession': 'GSM4546601',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8325564',
#    'srr_ids': ['SRR11772383']},
#   'GSM4546602': {'submission-date': '2020-05-11',
#    'title': 'case5-skin1',
#    'accession': 'GSM4546602',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8325565',
#    'srr_ids': ['SRR11772384']},
#   'GSM4546603': {'submission-date': '2020-05-11',
#    'title': 'case5-bowel1',
#    'accession': 'GSM4546603',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8325566',
#    'srr_ids': ['SRR11772385']},
#   'GSM4546604': {'submission-date': '2020-05-11',
#    'title': 'case5-liver1',
#    'accession': 'GSM4546604',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8325567',
#    'srr_ids': ['SRR11772386']},
#   'GSM4546605': {'submission-date': '2020-05-11',
#    'title': 'case5-kidney1',
#    'accession': 'GSM4546605',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8325568',
#    'srr_ids': ['SRR11772387']},
#   'GSM4546606': {'submission-date': '2020-05-11',
#    'title': 'case5-heart1',
#    'accession': 'GSM4546606',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8325569',
#    'srr_ids': ['SRR11772388']},
#   'GSM4546607': {'submission-date': '2020-05-11',
#    'title': 'case5-marrow1',
#    'accession': 'GSM4546607',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8325570',
#    'srr_ids': ['SRR11772389']},
#   'GSM4546608': {'submission-date': '2020-05-11',
#    'title': 'NegControl1',
#    'accession': 'GSM4546608',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8325571',
#    'srr_ids': ['SRR11772390']},
#   'GSM4546609': {'submission-date': '2020-05-11',
#    'title': 'NegControl2',
#    'accession': 'GSM4546609',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8325572',
#    'srr_ids': ['SRR11772391']},
#   'GSM4546610': {'submission-date': '2020-05-11',
#    'title': 'NegControl3',
#    'accession': 'GSM4546610',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8325573',
#    'srr_ids': ['SRR11772392']},
#   'GSM4546611': {'submission-date': '2020-05-11',
#    'title': 'NegControl4',
#    'accession': 'GSM4546611',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8325574',
#    'srr_ids': ['SRR11772393']},
#   'GSM4546612': {'submission-date': '2020-05-11',
#    'title': 'NegControl5',
#    'accession': 'GSM4546612',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8325575',
#    'srr_ids': ['SRR11772394']},
#   'GSM4698520': {'submission-date': '2020-07-28',
#    'title': 'case10-liver1',
#    'accession': 'GSM4698520',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839844',
#    'srr_ids': ['SRR12340057']},
#   'GSM4698521': {'submission-date': '2020-07-28',
#    'title': 'case10-lung1',
#    'accession': 'GSM4698521',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839845',
#    'srr_ids': ['SRR12340058']},
#   'GSM4698522': {'submission-date': '2020-07-28',
#    'title': 'case10-lung2',
#    'accession': 'GSM4698522',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839846',
#    'srr_ids': ['SRR12340059']},
#   'GSM4698523': {'submission-date': '2020-07-28',
#    'title': 'case10-lung3',
#    'accession': 'GSM4698523',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839847',
#    'srr_ids': ['SRR12340060']},
#   'GSM4698524': {'submission-date': '2020-07-28',
#    'title': 'case11-bowel1',
#    'accession': 'GSM4698524',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839848',
#    'srr_ids': ['SRR12340061']},
#   'GSM4698525': {'submission-date': '2020-07-28',
#    'title': 'case11-kidney1',
#    'accession': 'GSM4698525',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839849',
#    'srr_ids': ['SRR12340062']},
#   'GSM4698526': {'submission-date': '2020-07-28',
#    'title': 'case11-lung1',
#    'accession': 'GSM4698526',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839850',
#    'srr_ids': ['SRR12340063']},
#   'GSM4698527': {'submission-date': '2020-07-28',
#    'title': 'case11-lung2',
#    'accession': 'GSM4698527',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839851',
#    'srr_ids': ['SRR12340064']},
#   'GSM4698528': {'submission-date': '2020-07-28',
#    'title': 'case11-lung3',
#    'accession': 'GSM4698528',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839852',
#    'srr_ids': ['SRR12340065']},
#   'GSM4698529': {'submission-date': '2020-07-28',
#    'title': 'case12-liver1',
#    'accession': 'GSM4698529',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839853',
#    'srr_ids': ['SRR12340066']},
#   'GSM4698530': {'submission-date': '2020-07-28',
#    'title': 'case3-liver1',
#    'accession': 'GSM4698530',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839854',
#    'srr_ids': ['SRR12340067']},
#   'GSM4698531': {'submission-date': '2020-07-28',
#    'title': 'case6-lung1',
#    'accession': 'GSM4698531',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839855',
#    'srr_ids': ['SRR12340068']},
#   'GSM4698532': {'submission-date': '2020-07-28',
#    'title': 'case6-lung2',
#    'accession': 'GSM4698532',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839856',
#    'srr_ids': ['SRR12340069']},
#   'GSM4698533': {'submission-date': '2020-07-28',
#    'title': 'case6-lung3',
#    'accession': 'GSM4698533',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839857',
#    'srr_ids': ['SRR12340070']},
#   'GSM4698534': {'submission-date': '2020-07-28',
#    'title': 'case6-lung4',
#    'accession': 'GSM4698534',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839858',
#    'srr_ids': ['SRR12340071']},
#   'GSM4698535': {'submission-date': '2020-07-28',
#    'title': 'case6-lung5',
#    'accession': 'GSM4698535',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839859',
#    'srr_ids': ['SRR12340072']},
#   'GSM4698536': {'submission-date': '2020-07-28',
#    'title': 'case7-lung1',
#    'accession': 'GSM4698536',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839860',
#    'srr_ids': ['SRR12340073']},
#   'GSM4698537': {'submission-date': '2020-07-28',
#    'title': 'case7-lung2',
#    'accession': 'GSM4698537',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839861',
#    'srr_ids': ['SRR12340074']},
#   'GSM4698538': {'submission-date': '2020-07-28',
#    'title': 'case7-lung3',
#    'accession': 'GSM4698538',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839862',
#    'srr_ids': ['SRR12340075']},
#   'GSM4698539': {'submission-date': '2020-07-28',
#    'title': 'case7-lung4',
#    'accession': 'GSM4698539',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839863',
#    'srr_ids': ['SRR12340076']},
#   'GSM4698540': {'submission-date': '2020-07-28',
#    'title': 'case7-lung5',
#    'accession': 'GSM4698540',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839864',
#    'srr_ids': ['SRR12340077']},
#   'GSM4698541': {'submission-date': '2020-07-28',
#    'title': 'case8-bowel1',
#    'accession': 'GSM4698541',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839865',
#    'srr_ids': ['SRR12340078']},
#   'GSM4698542': {'submission-date': '2020-07-28',
#    'title': 'case8-heart1',
#    'accession': 'GSM4698542',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839866',
#    'srr_ids': ['SRR12340079']},
#   'GSM4698543': {'submission-date': '2020-07-28',
#    'title': 'case8-liver1',
#    'accession': 'GSM4698543',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839867',
#    'srr_ids': ['SRR12340080']},
#   'GSM4698544': {'submission-date': '2020-07-28',
#    'title': 'case8-lung1',
#    'accession': 'GSM4698544',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839868',
#    'srr_ids': ['SRR12340081']},
#   'GSM4698545': {'submission-date': '2020-07-28',
#    'title': 'case8-lung2',
#    'accession': 'GSM4698545',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839869',
#    'srr_ids': ['SRR12340082']},
#   'GSM4698546': {'submission-date': '2020-07-28',
#    'title': 'case8-lung3',
#    'accession': 'GSM4698546',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839870',
#    'srr_ids': ['SRR12340083']},
#   'GSM4698547': {'submission-date': '2020-07-28',
#    'title': 'case8-lung4',
#    'accession': 'GSM4698547',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839871',
#    'srr_ids': ['SRR12340084']},
#   'GSM4698548': {'submission-date': '2020-07-28',
#    'title': 'case8-lung5',
#    'accession': 'GSM4698548',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839872',
#    'srr_ids': ['SRR12340085']},
#   'GSM4698549': {'submission-date': '2020-07-28',
#    'title': 'case9-lung1',
#    'accession': 'GSM4698549',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839873',
#    'srr_ids': ['SRR12340086']},
#   'GSM4698550': {'submission-date': '2020-07-28',
#    'title': 'case9-lung2',
#    'accession': 'GSM4698550',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839874',
#    'srr_ids': ['SRR12340087']},
#   'GSM4698551': {'submission-date': '2020-07-28',
#    'title': 'case9-lung3',
#    'accession': 'GSM4698551',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839875',
#    'srr_ids': ['SRR12340088']},
#   'GSM4698552': {'submission-date': '2020-07-28',
#    'title': 'case9-lung4',
#    'accession': 'GSM4698552',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839876',
#    'srr_ids': ['SRR12340089']},
#   'GSM4698553': {'submission-date': '2020-07-28',
#    'title': 'case9-lung5',
#    'accession': 'GSM4698553',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839877',
#    'srr_ids': ['SRR12340090']},
#   'GSM4698554': {'submission-date': '2020-07-28',
#    'title': 'caseA-lung',
#    'accession': 'GSM4698554',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839878',
#    'srr_ids': ['SRR12340091']},
#   'GSM4698555': {'submission-date': '2020-07-28',
#    'title': 'caseB-lung',
#    'accession': 'GSM4698555',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839879',
#    'srr_ids': ['SRR12340092']},
#   'GSM4698556': {'submission-date': '2020-07-28',
#    'title': 'caseC-lung',
#    'accession': 'GSM4698556',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839880',
#    'srr_ids': ['SRR12340093']},
#   'GSM4698557': {'submission-date': '2020-07-28',
#    'title': 'caseD-lung',
#    'accession': 'GSM4698557',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839881',
#    'srr_ids': ['SRR12340094']},
#   'GSM4698558': {'submission-date': '2020-07-28',
#    'title': 'caseE-lung',
#    'accession': 'GSM4698558',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839882',
#    'srr_ids': ['SRR12340095']},
#   'GSM4698559': {'submission-date': '2020-07-28',
#    'title': 'caseF-lung',
#    'accession': 'GSM4698559',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839883',
#    'srr_ids': ['SRR12340096']},
#   'GSM4698560': {'submission-date': '2020-07-28',
#    'title': 'caseG-lung',
#    'accession': 'GSM4698560',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839884',
#    'srr_ids': ['SRR12340097']},
#   'GSM4698561': {'submission-date': '2020-07-28',
#    'title': 'caseH-lung',
#    'accession': 'GSM4698561',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839885',
#    'srr_ids': ['SRR12340098']},
#   'GSM4698562': {'submission-date': '2020-07-28',
#    'title': 'caseI-lung',
#    'accession': 'GSM4698562',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839886',
#    'srr_ids': ['SRR12340099']},
#   'GSM4698563': {'submission-date': '2020-07-28',
#    'title': 'caseJ-lung',
#    'accession': 'GSM4698563',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839887',
#    'srr_ids': ['SRR12340100']},
#   'GSM4698564': {'submission-date': '2020-07-28',
#    'title': 'caseP1-placenta1',
#    'accession': 'GSM4698564',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839888',
#    'srr_ids': ['SRR12340101']},
#   'GSM4698565': {'submission-date': '2020-07-28',
#    'title': 'caseP1-placenta2',
#    'accession': 'GSM4698565',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839889',
#    'srr_ids': ['SRR12340102']},
#   'GSM4698566': {'submission-date': '2020-07-28',
#    'title': 'caseP2-placenta1',
#    'accession': 'GSM4698566',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839890',
#    'srr_ids': ['SRR12340103']},
#   'GSM4698567': {'submission-date': '2020-07-28',
#    'title': 'caseP2-placenta2',
#    'accession': 'GSM4698567',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839891',
#    'srr_ids': ['SRR12340104']},
#   'GSM4698568': {'submission-date': '2020-07-28',
#    'title': 'caseP3-placenta1',
#    'accession': 'GSM4698568',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839892',
#    'srr_ids': ['SRR12340105']},
#   'GSM4698569': {'submission-date': '2020-07-28',
#    'title': 'caseP3-placenta2',
#    'accession': 'GSM4698569',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839893',
#    'srr_ids': ['SRR12340106']},
#   'GSM4698570': {'submission-date': '2020-07-28',
#    'title': 'caseP4-placenta1',
#    'accession': 'GSM4698570',
#    'organism': 'Homo sapiens',
#    'sra_link': 'https://www.ncbi.nlm.nih.gov/sra?term=SRX8839894',
#    'srr_ids': ['SRR12340107']}},
#  'submission-date': '2020-05-11',
#  'title': 'Spectrum of Viral Load and Host Response Seen in Autopsies of SARS-CoV-2 Infected Lungs',
#  'accession': 'GSE150316',
#  'abstract': '\nThe relationship of SARS-CoV-2 lung infection and severity of pulmonary disease is not fully understood. We visualized viral RNA by in situ hybridization and assessed the immune infiltrate using immunohistochemistry and total RNA sequencing on five COVID-19 positive patients.  Patients with high levels of viral RNA showed hyaline membranes on histology, extensive pneumocyte loss, low T-cell numbers and were enriched for the interferon gene signature, while patients with lower levels of viral RNA showed lower numbers of T-cells and CD8 cells and were enriched for fibrosis-associated genes. The study highlights the need to assess both pulmonary viral load and immune response in patients with severe COVID-19 infection.\n    ',
#  'overall-design': '\nAutopsy samples from patients deceased due to SARS-Cov2 infection were collected for total RNA-seq analysis to assess viral load and immune response.\n    ',
#  'type': 'Expression profiling by high throughput sequencing'}

# %%
script_lines = []
for exp_accession, contents in study_dict["experiments"].items():
    if "lung" in contents["title"].lower():
        script_lines.append("echo {}".format(exp_accession))
        this_line = "fasterq-dump -p -o fastqs/{}.fastq {}".format(exp_accession, contents["srr_ids"][0])
        print(this_line)
        script_lines.append(this_line)
        script_lines.append("gzip fastqs/{}*fastq".format(exp_accession))
        script_lines.append("############################")
# Out:
# fasterq-dump -p -o fastqs/GSM4546576.fastq SRR11772358
# fasterq-dump -p -o fastqs/GSM4546577.fastq SRR11772359
# fasterq-dump -p -o fastqs/GSM4546578.fastq SRR11772360
# fasterq-dump -p -o fastqs/GSM4546579.fastq SRR11772361
# fasterq-dump -p -o fastqs/GSM4546581.fastq SRR11772363
# fasterq-dump -p -o fastqs/GSM4546582.fastq SRR11772364
# fasterq-dump -p -o fastqs/GSM4546584.fastq SRR11772366
# fasterq-dump -p -o fastqs/GSM4546586.fastq SRR11772368
# fasterq-dump -p -o fastqs/GSM4546588.fastq SRR11772370
# fasterq-dump -p -o fastqs/GSM4546589.fastq SRR11772371
# fasterq-dump -p -o fastqs/GSM4546592.fastq SRR11772374
# fasterq-dump -p -o fastqs/GSM4546596.fastq SRR11772378
# fasterq-dump -p -o fastqs/GSM4546597.fastq SRR11772379
# fasterq-dump -p -o fastqs/GSM4546598.fastq SRR11772380
# fasterq-dump -p -o fastqs/GSM4546599.fastq SRR11772381
# fasterq-dump -p -o fastqs/GSM4546601.fastq SRR11772383
# fasterq-dump -p -o fastqs/GSM4698521.fastq SRR12340058
# fasterq-dump -p -o fastqs/GSM4698522.fastq SRR12340059
# fasterq-dump -p -o fastqs/GSM4698523.fastq SRR12340060
# fasterq-dump -p -o fastqs/GSM4698526.fastq SRR12340063
# fasterq-dump -p -o fastqs/GSM4698527.fastq SRR12340064
# fasterq-dump -p -o fastqs/GSM4698528.fastq SRR12340065
# fasterq-dump -p -o fastqs/GSM4698531.fastq SRR12340068
# fasterq-dump -p -o fastqs/GSM4698532.fastq SRR12340069
# fasterq-dump -p -o fastqs/GSM4698533.fastq SRR12340070
# fasterq-dump -p -o fastqs/GSM4698534.fastq SRR12340071
# fasterq-dump -p -o fastqs/GSM4698535.fastq SRR12340072
# fasterq-dump -p -o fastqs/GSM4698536.fastq SRR12340073
# fasterq-dump -p -o fastqs/GSM4698537.fastq SRR12340074
# fasterq-dump -p -o fastqs/GSM4698538.fastq SRR12340075
# fasterq-dump -p -o fastqs/GSM4698539.fastq SRR12340076
# fasterq-dump -p -o fastqs/GSM4698540.fastq SRR12340077
# fasterq-dump -p -o fastqs/GSM4698544.fastq SRR12340081
# fasterq-dump -p -o fastqs/GSM4698545.fastq SRR12340082
# fasterq-dump -p -o fastqs/GSM4698546.fastq SRR12340083
# fasterq-dump -p -o fastqs/GSM4698547.fastq SRR12340084
# fasterq-dump -p -o fastqs/GSM4698548.fastq SRR12340085
# fasterq-dump -p -o fastqs/GSM4698549.fastq SRR12340086
# fasterq-dump -p -o fastqs/GSM4698550.fastq SRR12340087
# fasterq-dump -p -o fastqs/GSM4698551.fastq SRR12340088
# fasterq-dump -p -o fastqs/GSM4698552.fastq SRR12340089
# fasterq-dump -p -o fastqs/GSM4698553.fastq SRR12340090
# fasterq-dump -p -o fastqs/GSM4698554.fastq SRR12340091
# fasterq-dump -p -o fastqs/GSM4698555.fastq SRR12340092
# fasterq-dump -p -o fastqs/GSM4698556.fastq SRR12340093
# fasterq-dump -p -o fastqs/GSM4698557.fastq SRR12340094
# fasterq-dump -p -o fastqs/GSM4698558.fastq SRR12340095
# fasterq-dump -p -o fastqs/GSM4698559.fastq SRR12340096
# fasterq-dump -p -o fastqs/GSM4698560.fastq SRR12340097
# fasterq-dump -p -o fastqs/GSM4698561.fastq SRR12340098
# fasterq-dump -p -o fastqs/GSM4698562.fastq SRR12340099
# fasterq-dump -p -o fastqs/GSM4698563.fastq SRR12340100

# %%
with open("download_srrs.sh", "w") as output_stream:
    print("\n".join(script_lines), file = output_stream)

# %%
! cat download_srrs.sh
# Out:
# echo GSM4546576
# fasterq-dump -p -o fastqs/GSM4546576.fastq SRR11772358
# gzip fastqs/GSM4546576*fastq
# ############################
# echo GSM4546577
# fasterq-dump -p -o fastqs/GSM4546577.fastq SRR11772359
# gzip fastqs/GSM4546577*fastq
# ############################
# echo GSM4546578
# fasterq-dump -p -o fastqs/GSM4546578.fastq SRR11772360
# gzip fastqs/GSM4546578*fastq
# ############################
# echo GSM4546579
# fasterq-dump -p -o fastqs/GSM4546579.fastq SRR11772361
# gzip fastqs/GSM4546579*fastq
# ############################
# echo GSM4546581
# fasterq-dump -p -o fastqs/GSM4546581.fastq SRR11772363
# gzip fastqs/GSM4546581*fastq
# ############################
# echo GSM4546582
# fasterq-dump -p -o fastqs/GSM4546582.fastq SRR11772364
# gzip fastqs/GSM4546582*fastq
# ############################
# echo GSM4546584
# fasterq-dump -p -o fastqs/GSM4546584.fastq SRR11772366
# gzip fastqs/GSM4546584*fastq
# ############################
# echo GSM4546586
# fasterq-dump -p -o fastqs/GSM4546586.fastq SRR11772368
# gzip fastqs/GSM4546586*fastq
# ############################
# echo GSM4546588
# fasterq-dump -p -o fastqs/GSM4546588.fastq SRR11772370
# gzip fastqs/GSM4546588*fastq
# ############################
# echo GSM4546589
# fasterq-dump -p -o fastqs/GSM4546589.fastq SRR11772371
# gzip fastqs/GSM4546589*fastq
# ############################
# echo GSM4546592
# fasterq-dump -p -o fastqs/GSM4546592.fastq SRR11772374
# gzip fastqs/GSM4546592*fastq
# ############################
# echo GSM4546596
# fasterq-dump -p -o fastqs/GSM4546596.fastq SRR11772378
# gzip fastqs/GSM4546596*fastq
# ############################
# echo GSM4546597
# fasterq-dump -p -o fastqs/GSM4546597.fastq SRR11772379
# gzip fastqs/GSM4546597*fastq
# ############################
# echo GSM4546598
# fasterq-dump -p -o fastqs/GSM4546598.fastq SRR11772380
# gzip fastqs/GSM4546598*fastq
# ############################
# echo GSM4546599
# fasterq-dump -p -o fastqs/GSM4546599.fastq SRR11772381
# gzip fastqs/GSM4546599*fastq
# ############################
# echo GSM4546601
# fasterq-dump -p -o fastqs/GSM4546601.fastq SRR11772383
# gzip fastqs/GSM4546601*fastq
# ############################
# echo GSM4698521
# fasterq-dump -p -o fastqs/GSM4698521.fastq SRR12340058
# gzip fastqs/GSM4698521*fastq
# ############################
# echo GSM4698522
# fasterq-dump -p -o fastqs/GSM4698522.fastq SRR12340059
# gzip fastqs/GSM4698522*fastq
# ############################
# echo GSM4698523
# fasterq-dump -p -o fastqs/GSM4698523.fastq SRR12340060
# gzip fastqs/GSM4698523*fastq
# ############################
# echo GSM4698526
# fasterq-dump -p -o fastqs/GSM4698526.fastq SRR12340063
# gzip fastqs/GSM4698526*fastq
# ############################
# echo GSM4698527
# fasterq-dump -p -o fastqs/GSM4698527.fastq SRR12340064
# gzip fastqs/GSM4698527*fastq
# ############################
# echo GSM4698528
# fasterq-dump -p -o fastqs/GSM4698528.fastq SRR12340065
# gzip fastqs/GSM4698528*fastq
# ############################
# echo GSM4698531
# fasterq-dump -p -o fastqs/GSM4698531.fastq SRR12340068
# gzip fastqs/GSM4698531*fastq
# ############################
# echo GSM4698532
# fasterq-dump -p -o fastqs/GSM4698532.fastq SRR12340069
# gzip fastqs/GSM4698532*fastq
# ############################
# echo GSM4698533
# fasterq-dump -p -o fastqs/GSM4698533.fastq SRR12340070
# gzip fastqs/GSM4698533*fastq
# ############################
# echo GSM4698534
# fasterq-dump -p -o fastqs/GSM4698534.fastq SRR12340071
# gzip fastqs/GSM4698534*fastq
# ############################
# echo GSM4698535
# fasterq-dump -p -o fastqs/GSM4698535.fastq SRR12340072
# gzip fastqs/GSM4698535*fastq
# ############################
# echo GSM4698536
# fasterq-dump -p -o fastqs/GSM4698536.fastq SRR12340073
# gzip fastqs/GSM4698536*fastq
# ############################
# echo GSM4698537
# fasterq-dump -p -o fastqs/GSM4698537.fastq SRR12340074
# gzip fastqs/GSM4698537*fastq
# ############################
# echo GSM4698538
# fasterq-dump -p -o fastqs/GSM4698538.fastq SRR12340075
# gzip fastqs/GSM4698538*fastq
# ############################
# echo GSM4698539
# fasterq-dump -p -o fastqs/GSM4698539.fastq SRR12340076
# gzip fastqs/GSM4698539*fastq
# ############################
# echo GSM4698540
# fasterq-dump -p -o fastqs/GSM4698540.fastq SRR12340077
# gzip fastqs/GSM4698540*fastq
# ############################
# echo GSM4698544
# fasterq-dump -p -o fastqs/GSM4698544.fastq SRR12340081
# gzip fastqs/GSM4698544*fastq
# ############################
# echo GSM4698545
# fasterq-dump -p -o fastqs/GSM4698545.fastq SRR12340082
# gzip fastqs/GSM4698545*fastq
# ############################
# echo GSM4698546
# fasterq-dump -p -o fastqs/GSM4698546.fastq SRR12340083
# gzip fastqs/GSM4698546*fastq
# ############################
# echo GSM4698547
# fasterq-dump -p -o fastqs/GSM4698547.fastq SRR12340084
# gzip fastqs/GSM4698547*fastq
# ############################
# echo GSM4698548
# fasterq-dump -p -o fastqs/GSM4698548.fastq SRR12340085
# gzip fastqs/GSM4698548*fastq
# ############################
# echo GSM4698549
# fasterq-dump -p -o fastqs/GSM4698549.fastq SRR12340086
# gzip fastqs/GSM4698549*fastq
# ############################
# echo GSM4698550
# fasterq-dump -p -o fastqs/GSM4698550.fastq SRR12340087
# gzip fastqs/GSM4698550*fastq
# ############################
# echo GSM4698551
# fasterq-dump -p -o fastqs/GSM4698551.fastq SRR12340088
# gzip fastqs/GSM4698551*fastq
# ############################
# echo GSM4698552
# fasterq-dump -p -o fastqs/GSM4698552.fastq SRR12340089
# gzip fastqs/GSM4698552*fastq
# ############################
# echo GSM4698553
# fasterq-dump -p -o fastqs/GSM4698553.fastq SRR12340090
# gzip fastqs/GSM4698553*fastq
# ############################
# echo GSM4698554
# fasterq-dump -p -o fastqs/GSM4698554.fastq SRR12340091
# gzip fastqs/GSM4698554*fastq
# ############################
# echo GSM4698555
# fasterq-dump -p -o fastqs/GSM4698555.fastq SRR12340092
# gzip fastqs/GSM4698555*fastq
# ############################
# echo GSM4698556
# fasterq-dump -p -o fastqs/GSM4698556.fastq SRR12340093
# gzip fastqs/GSM4698556*fastq
# ############################
# echo GSM4698557
# fasterq-dump -p -o fastqs/GSM4698557.fastq SRR12340094
# gzip fastqs/GSM4698557*fastq
# ############################
# echo GSM4698558
# fasterq-dump -p -o fastqs/GSM4698558.fastq SRR12340095
# gzip fastqs/GSM4698558*fastq
# ############################
# echo GSM4698559
# fasterq-dump -p -o fastqs/GSM4698559.fastq SRR12340096
# gzip fastqs/GSM4698559*fastq
# ############################
# echo GSM4698560
# fasterq-dump -p -o fastqs/GSM4698560.fastq SRR12340097
# gzip fastqs/GSM4698560*fastq
# ############################
# echo GSM4698561
# fasterq-dump -p -o fastqs/GSM4698561.fastq SRR12340098
# gzip fastqs/GSM4698561*fastq
# ############################
# echo GSM4698562
# fasterq-dump -p -o fastqs/GSM4698562.fastq SRR12340099
# gzip fastqs/GSM4698562*fastq
# ############################
# echo GSM4698563
# fasterq-dump -p -o fastqs/GSM4698563.fastq SRR12340100
# gzip fastqs/GSM4698563*fastq
# ############################
